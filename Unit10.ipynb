# %% [markdown]
# # UNIT 10 우리 동네 인구 구조를 산점도로 나타내기

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm 
fm._rebuild()

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumSquareRound',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareRoundR.ttf'),
#  ('NanumMyeongjo',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjo.ttf'),
#  ('NanumMyeongjo',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjoBold.ttf'),
#  ('NanumSquareRound',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareRoundB.ttf'),
#  ('NanumBarunGothic',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBarunGothic.ttf'),
#  ('NanumSquare',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareR.ttf'),
#  ('NanumGothic',
# ...

# %% [markdown]
# ## 1. 꺾은선 그래프로 표현하기
# ---

# %% [markdown]
# 연령대별 성별 비율 인구 데이터를 꺾은선 그래프로 표현하려면 남성 데이터와 여성 데이터를 각각 리스트에 저장해야한다.

# %%
import csv
f = open('202101_gender.csv', encoding='cp949')
data = csv.reader(f)

m = []
f = []

# %% [markdown]
# `name`이라는 변수에 알고 싶은 지역의 이름을 입력해서 남성과 여성의 연령별 인구를 각 리스트에 추가한다.

# %%
name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i])) # 남성 데이터를 저장하기
            f.append(int(row[i+103])) # 여성 테이터 저장하기
        break
# Out:
# 궁금한 동네를 입력해주세요:청담동

# %% [markdown]
# 마지막으로 남성과 여성 데이터를 꺾은선 그래프로 나타낸다.

# %%
plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. 막대그래프로 표현하기
# ---
# 연령대별 남성 인구에서 여성 인구를 뺀 값을 `result`라는 리스트에 추가한다.

# %%
import csv
f = open('202101_gender.csv', encoding='cp949')
data = csv.reader(f)

result = []

name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            result.append(int(row[i]) - int(row[i+103]))
        break
# Out:
# 궁금한 동네를 입력해주세요:청담동

# %%
plt.figure(figsize=(10, 5))     
plt.bar(range(101), result)
plt.show()

# %% [markdown]
# ## 3. 산점도로 표현하기
# ---
# 산점도는 가로축과 세로축을 기준으로 두 요소가 서로 어떤 관례를 맺고 있는지를 파악하기 쉽게 나타낸 그래프이다.
#
# <img src="10-3.jpg" alt="jeju" />
#
# 위 그림에는 다양한 색상의 점이 있다. 이 점들은 연령대에 따른 인구를 뜻하며, 그래프 오른쪽에 있는 컬러바를 참고하여 각 점의 색깔로 나이대를 알 수 있다.
#
# 또한, 여기에서 대각선으로 그려진 선은 남성과 여성이 동일한 비율일때를 의미한다.

# %% [markdown]
# ## 4. scatter() 함수로 표현하기
# ---
# 산점도는 `scatter()` 함수로 표현할 수 있다. 산점도는 `x`축과 `y`축에 해당하는 데이터의 상관관계를 표현할때 사용하며 점이 흩어져있는 그래프라는 의미이다. `scatter()` 함수는 `bar()` 함수와 비슷하게 `x`축에 해당하는 데이터와 `y`축에 해당하는 데이터를 각각 넣으면 그에 해당하는 산점도가 그려진다.

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40])
plt.show()

# %% [markdown]
# ## 버블 차트로 표현하기
# ---
# `scatter()` 함수는 버블 차트를 그릴 때도 사용할 수 있다.

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [100,200,250,300])
plt.show()

# %% [markdown]
# 여기에 `c`라는 속성을 추가하면 각 점의 색상도 정할 수 있다.

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = ['red','blue','green','gold'])
plt.show()

# %% [markdown]
# `colorbar()` 함수를 사용하면 그래프 옆에 컬러바를 추가할 수 있다.

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = range(4))
plt.colorbar()
plt.show()

# %% [markdown]
# 그리고 `cmap`이라는 컬러맵 속성을 사용하면 컬러바에 사용될 색상의 종류를 정할 수 있다.

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c =range(4), cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# 이번에는 랜덤 함수를 이용해 위치와 크기가 서로 다른 100개의 점을 만들었다.

# %%
import random

x = []
y = []
size = []
for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.style.use('ggplot')
plt.scatter(x, y, s = size)
plt.show()

# %% [markdown]
# 컬러바를 넣어보자.

# %%
plt.scatter(x, y, s = size, c = size, cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# 작은 점이 큰 점에 가려진다. 이럴 떄는 `alpha` 속성으로 투명도를 조절할 수 있다. 0에 가까울수록 투명하고, 1에 가까울수록 불투명하다.

# %%
plt.scatter(x, y, s = size, c = size, cmap='jet', alpha =0.7)
plt.colorbar()
plt.show()

# %% [markdown]
# ## 6. 제주도의 연령대별 성별 비율을 산점도로 표현하기
# ---

# %%
f = open('202101_gender.csv', encoding='cp949')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(int(i.replace(',', '')))
        for i in row[106:] :
            f.append(int(i.replace(',', '')))
        break

plt.style.use('ggplot')
plt.scatter(m, f)
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도

# %% [markdown]
# 연령에 따른 컬러맵을 적용한다. 추세선을 그려 어떤 성별의 인구가 많은지 한눈에 들어오게 한다.

# %%
plt.style.use('ggplot')
plt.scatter(m, f, c =range(101), alpha=0.5, cmap='jet') # 컬러맵 적용
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g') # 추세선 추가
plt.show()

# %% [markdown]
# 연령별 남성과 여성 인구수를 합친 값을 `size` 리스트에 넣어 점의 크기를 표현한다. 이때 `math` 라이브러리에 있는 제곱근 함수인 `sqrt()`를 사용하여 점의 크기를 적절히 조절하고 x, y축의 이름을 `xlabel()`, `ylabel()` 함수로 정한다.

# %%
import csv
import math
f = open('gender.csv')
data = csv.reader(f)
m = []
f = []
size = []
name = input('궁금한 동네를 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) : 
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i]) + int(row[i+103])))
        break
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='Malgun Gothic')
plt.figure(figsize = (10,5), dpi=300)            
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m, f, s = size, c = range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g')
plt.xlabel('남성 인구 수')
plt.ylabel('여성 인구 수')
plt.show()

# %%
import math

f = open('202101_gender.csv', encoding='cp949')
data = csv.reader(f)

m = []
f = []
size = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) : 
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i]) + int(row[i+103])))
        break

plt.style.use('ggplot')
plt.rc('font',family='NanumGothic')
plt.figure(figsize = (10,5), dpi=300)            
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m, f, s = size, c = range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g')
plt.xlabel('남성 인구 수')
plt.ylabel('여성 인구 수')
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 청담동
