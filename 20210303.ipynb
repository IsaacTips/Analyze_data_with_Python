# %%
import matplotlib
import matplotlib.font_manager as fm 
fm._rebuild()

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumMyeongjo',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjoBold.ttf'),
#  ('NanumMyeongjo',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumMyeongjo.ttf'),
#  ('NanumSquare',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareR.ttf'),
#  ('NanumGothic',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumGothic.ttf'),
#  ('NanumSquareRound',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumSquareRoundR.ttf'),
#  ('NanumBarunGothic',
#   '/home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/NanumBarunGothicBold.ttf'),
#  ('NanumGothic',
# ...

# %%
print('둔산1동' in '대전광역시 서구 둔산1동(3017063000)')
print('둔산2동' in '대전광역시 서구 둔산2동(3017064000)')
print('둔산3동' in '대전광역시 서구 둔산3동(3017066000)')
print('은행선화동' in '대전광역시 중구 은행선화동(3014053500)')
print('월평1동' in '대전광역시 서구 월평1동(3017058600)')
print('월평2동' in '대전광역시 서구 월평2동(3017058700)')
print('탄방동' in '대전광역시 서구 탄방동(3017055500)')
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
import csv

f = open('202101_age.csv',  encoding='cp949')
data = csv.reader(f)

doonsan1 = [] # 빈리스트 만들기
doonsan2 = [] # 빈리스트 만들기
doonsan3 = [] # 빈리스트 만들기
bank = [] # 빈리스트 만들기
wol1 = [] # 빈리스트 만들기
wol2 = [] # 빈리스트 만들기
tan = [] # 빈리스트 만들기

for row in data :
    if '둔산1동' in row[0] : # '둔산1동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            doonsan1.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기
    if '둔산2동' in row[0] : # '둔산2동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            doonsan2.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기
    if '둔산3동' in row[0] : # '둔산3동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            doonsan3.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기                  
    if '은행선화동' in row[0] : # '은행선화동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            bank.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기                     
    if '월평1동' in row[0] : # '월평1동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            wol1.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기               
    if '월평2동' in row[0] : # '월평2동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            wol2.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기             
    if '탄방동' in row[0] : # '탄방동'이 포함된 행정구역 찾기
        for i in row[3:] : # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            tan.append(int(i)) # 해당 연령의 인구수 리스트에 순서대로 저장하기                       
            
    
print(doonsan1) # 0세부터 100세 이상까지의 인구수 출력하기
print(doonsan2) # 0세부터 100세 이상까지의 인구수 출력하기
print(doonsan3) # 0세부터 100세 이상까지의 인구수 출력하기
print(bank) # 0세부터 100세 이상까지의 인구수 출력하기
print(wol1) # 0세부터 100세 이상까지의 인구수 출력하기
print(wol2) # 0세부터 100세 이상까지의 인구수 출력하기
print(tan) # 0세부터 100세 이상까지의 인구수 출력하기
# Out:
# [33, 46, 58, 96, 117, 168, 228, 241, 311, 303, 349, 337, 405, 380, 376, 303, 339, 366, 306, 246, 284, 200, 184, 171, 166, 152, 156, 143, 124, 118, 101, 100, 99, 108, 104, 125, 132, 144, 215, 290, 320, 370, 334, 373, 435, 420, 408, 434, 437, 460, 403, 348, 328, 294, 196, 178, 178, 160, 181, 182, 190, 158, 153, 126, 140, 137, 113, 118, 105, 98, 99, 101, 98, 89, 87, 64, 76, 53, 74, 77, 62, 56, 56, 23, 39, 36, 39, 20, 12, 22, 19, 13, 9, 6, 6, 2, 3, 6, 1, 0, 3]
# [214, 253, 261, 295, 357, 332, 368, 359, 384, 370, 389, 372, 392, 418, 394, 416, 468, 492, 497, 521, 620, 548, 538, 572, 535, 580, 572, 501, 530, 544, 518, 489, 528, 498, 486, 507, 493, 579, 631, 612, 580, 583, 553, 529, 610, 633, 640, 720, 783, 804, 770, 775, 771, 661, 584, 588, 555, 480, 553, 575, 564, 457, 369, 414, 379, 349, 290, 235, 238, 166, 164, 149, 130, 128, 106, 98, 104, 88, 123, 94, 82, 86, 65, 62, 61, 49, 43, 42, 32, 22, 18, 13, 13, 11, 7, 7, 3, 1, 2, 0, 4]
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('둔산1동 지역의 남녀 성별 비율')
plt.plot(doonsan1)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('둔산2동 지역의 남녀 성별 비율')
plt.plot(doonsan2)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('둔산3동 지역의 남녀 성별 비율')
plt.plot(doonsan3)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('은행선화동 지역의 남녀 성별 비율')
plt.plot(bank)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('월평1동 지역의 남녀 성별 비율')
plt.plot(wol1)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('월평2동 지역의 남녀 성별 비율')
plt.plot(wol2)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title('탄방동 지역의 남녀 성별 비율')
plt.plot(tan)
plt.show()

# %%
import csv
f = open('202101_age.csv', encoding='cp949')
data = csv.reader(f)

result1 = []
result2 = []
result3 = []
result4 = []
result5 = []
result6 = []
result7 = []
result8 = []
result9 = []

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : (최대 9개)') # 인구 구조가 궁금한 지역의 이름을 input() 함수로 입력받는다

# dong1 = name.split("")[0]
# dong2 = name.split("")[1]
# dong3 = name.split("")[2]



for row in data :
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result1.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result2.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result3.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result4.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result5.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result6.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result7.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result8.append(int(i))
    except IndexError:
        pass
    
    try:
        if name.split(" ")[0] in row[0] : # 입력받은 내용이 포함된 값을 찾는다
            for i in row[3:] :
                result9.append(int(i))
    except IndexError:
        pass
            
import matplotlib.pyplot as plt

plt.rc('font', family ='NanumGothic')
plt.figure(figsize=(10,5))
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title(name + ' 지역의 연령 그래프')
# try:
plt.plot(result1, label=name.split(" ")[0])
plt.plot(result2, label=name.split(" ")[1])
plt.plot(result3, label=name.split(" ")[2])
plt.plot(result4, label=name.split(" ")[3])
plt.plot(result5, label=name.split(" ")[4])
plt.plot(result6, label=name.split(" ")[5])
plt.plot(result7, label=name.split(" ")[6])
plt.plot(result8, label=name.split(" ")[7])
plt.plot(result9, label=name.split(" ")[8])
# except IndexError:
#         pass    
plt.xlabel('age')
plt.ylabel('population')
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : (최대 9개)둔산1동 둔산2동 둔산3동 탄방동 괴정동 월평1동 월평2동 가수원동 갈마동

# %%
f = open('202101_age.csv', encoding='cp949')
data = csv.reader(f)

result = []
#name[] = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
name_list = list(map(str, input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ').split()))
print(name_list)
#신도림, 둔산2동, 
for i,v in enumerate(name_list) :
    f = open('202101_age.csv', encoding='cp949')
    data = csv.reader(f)
    result_temp = []
    print(i)
    # print(v)
    name = name_list[i]
    #print(name_list[i])
    for row in data :  
        if name in row[0] :
          #print(name)
            for a in row[3:] :        
                result_temp.append(int(a)) # 시각화를 위해 리스트 내 문자열을 정수로 바꿔줌.         
            result.append(result_temp)
            #print(result_temp)            
    print(result[i])    
    plt.rc('font', family = 'NanumGothic')
    plt.title(name + '지역의 인구 구조')
    plt.style.use('ggplot')
    plt.plot(result[i])
    plt.show()
    plt.bar(range(101), result[i])
    plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 둔산1동 둔산2동 둔산3동 탄방동 괴정동 월평1동 월평2동 가수원동 갈마동
# ['둔산1동', '둔산2동', '둔산3동', '탄방동', '괴정동', '월평1동', '월평2동', '가수원동', '갈마동']
# 0
# [33, 46, 58, 96, 117, 168, 228, 241, 311, 303, 349, 337, 405, 380, 376, 303, 339, 366, 306, 246, 284, 200, 184, 171, 166, 152, 156, 143, 124, 118, 101, 100, 99, 108, 104, 125, 132, 144, 215, 290, 320, 370, 334, 373, 435, 420, 408, 434, 437, 460, 403, 348, 328, 294, 196, 178, 178, 160, 181, 182, 190, 158, 153, 126, 140, 137, 113, 118, 105, 98, 99, 101, 98, 89, 87, 64, 76, 53, 74, 77, 62, 56, 56, 23, 39, 36, 39, 20, 12, 22, 19, 13, 9, 6, 6, 2, 3, 6, 1, 0, 3]
# 1
# ...
